# %%
# randomNG = 'Philox'
# randomNG = 'PCG64DXSM'
# randomNG = 'MT19937'
# randomNG = 'SFC64'
import importlib

pass_abc ='xprobRRapril_'

# %%
import numpy as np
import time
import datetime
import numba
import concurrent.futures
from math import lgamma, floor
import numpy.random
# bitNG = getattr(numpy.random, randomNG)
from numpy.random import Generator, SeedSequence
from ill_confirm_bias_FNs_03_t0FAST_03cnt_vdisc_explore_prob import confirm_bias_full
np.set_printoptions(suppress=True)
# Out:
# /home/pallavi/python_pallavi_Dtop/confirm_bias_illusory_tuth_002/ill_confirm_bias_FNs_03_t0FAST_03cnt_vdisc_explore_prob.py:42: NumbaDeprecationWarning: The 'nopython' keyword argument was not supplied to the 'numba.jit' decorator. The implicit default value for this argument is currently False, but it will be changed to True in Numba 0.59.0. See https://numba.readthedocs.io/en/stable/reference/deprecation.html#deprecation-of-object-mode-fall-back-behaviour-when-using-jit for details.
#   def bbpmfNG(vk, vn, va, vb):
# /home/pallavi/python_pallavi_Dtop/confirm_bias_illusory_tuth_002/ill_confirm_bias_FNs_03_t0FAST_03cnt_vdisc_explore_prob.py:58: NumbaDeprecationWarning: The 'nopython' keyword argument was not supplied to the 'numba.jit' decorator. The implicit default value for this argument is currently False, but it will be changed to True in Numba 0.59.0. See https://numba.readthedocs.io/en/stable/reference/deprecation.html#deprecation-of-object-mode-fall-back-behaviour-when-using-jit for details.
#   def bbpmfCOARSEng(pulls6, aX, bX, aY, bY):
# /home/pallavi/python_pallavi_Dtop/confirm_bias_illusory_tuth_002/ill_confirm_bias_FNs_03_t0FAST_03cnt_vdisc_explore_prob.py:71: NumbaDeprecationWarning: The 'nopython' keyword argument was not supplied to the 'numba.jit' decorator. The implicit default value for this argument is currently False, but it will be changed to True in Numba 0.59.0. See https://numba.readthedocs.io/en/stable/reference/deprecation.html#deprecation-of-object-mode-fall-back-behaviour-when-using-jit for details.
#   def bbpmfCORarray(pulls7, params7, expect7, nag7, narms7, tol7):
# /home/pallavi/python_pallavi_Dtop/confirm_bias_illusory_tuth_002/ill_confirm_bias_FNs_03_t0FAST_03cnt_vdisc_explore_prob.py:89: NumbaDeprecationWarning: The 'nopython' keyword argument was not supplied to the 'numba.jit' decorator. The implicit default value for this argument is currently False, but it will be changed to True in Numba 0.59.0. See https://numba.readthedocs.io/en/stable/reference/deprecation.html#deprecation-of-object-mode-fall-back-behaviour-when-using-jit for details.
#   def abexpect(a1, b1):
# /home/pallavi/python_pallavi_Dtop/confirm_bias_illusory_tuth_002/ill_confirm_bias_FNs_03_t0FAST_03cnt_vdisc_explore_prob.py:95: NumbaDeprecationWarning: The 'nopython' keyword argument was not supplied to the 'numba.jit' decorator. The implicit default value for this argument is currently False, but it will be changed to True in Numba 0.59.0. See https://numba.readthedocs.io/en/stable/reference/deprecation.html#deprecation-of-object-mode-fall-back-behaviour-when-using-jit for details.
#   def agentexp(param1):
# /home/pallavi/python_pallavi_Dtop/confirm_bias_illusory_tuth_002/ill_confirm_bias_FNs_03_t0FAST_03cnt_vdisc_explore_prob.py:110: NumbaDeprecationWarning: The 'nopython' keyword argument was not supplied to the 'numba.jit' decorator. The implicit default value for this argument is currently False, but it will be changed to True in Numba 0.59.0. See https://numba.readthedocs.io/en/stable/reference/deprecation.html#deprecation-of-object-mode-fall-back-behaviour-when-using-jit for details.
#   def evid(pay2, exp2, idxa, idxb, explarray2):
# /home/pallavi/python_pallavi_Dtop/confirm_bias_illusory_tuth_002/ill_confirm_bias_FNs_03_t0FAST_03cnt_vdisc_explore_prob.py:152: NumbaDeprecationWarning: The 'nopython' keyword argument was not supplied to the 'numba.jit' decorator. The implicit default value for this argument is currently False, but it will be changed to True in Numba 0.59.0. See https://numba.readthedocs.io/en/stable/reference/deprecation.html#deprecation-of-object-mode-fall-back-behaviour-when-using-jit for details.
#   def agentstolpmfsCOARSE(agpmfCORtols3, memshare3, pulls3, nag3, params3, memevid3, memevidarms3, con3, tol3):
# /home/pallavi/python_pallavi_Dtop/confirm_bias_illusory_tuth_002/ill_confirm_bias_FNs_03_t0FAST_03cnt_vdisc_explore_prob.py:176: NumbaDeprecationWarning: The 'nopython' keyword argument was not supplied to the 'numba.jit' decorator. The implicit default value for this argument is currently False, but it will be changed to True in Numba 0.59.0. See https://numba.readthedocs.io/en/stable/reference/deprecation.html#deprecation-of-object-mode-fall-back-behaviour-when-using-jit for details.
#   def agentst0FAST(memshare3, memevid3, nag3, con3):
# /home/pallavi/python_pallavi_Dtop/confirm_bias_illusory_tuth_002/ill_confirm_bias_FNs_03_t0FAST_03cnt_vdisc_explore_prob.py:197: NumbaDeprecationWarning: The 'nopython' keyword argument was not supplied to the 'numba.jit' decorator. The implicit default value for this argument is currently False, but it will be changed to True in Numba 0.59.0. See https://numba.readthedocs.io/en/stable/reference/deprecation.html#deprecation-of-object-mode-fall-back-behaviour-when-using-jit for details.
#   def paramsupdate(vdisc4, memplay4, memevidplay4, perms4, memsuc4, memarms4, store4, memstore4, memshare4, pulls4, nag4, randunif4, tolpmfs4, memevid4, memevidarms4, params4):
# /home/pallavi/python_pallavi_Dtop/confirm_bias_illusory_tuth_002/ill_confirm_bias_FNs_03_t0FAST_03cnt_vdisc_explore_prob.py:231: NumbaDeprecationWarning: The 'nopython' keyword argument was not supplied to the 'numba.jit' decorator. The implicit default value for this argument is currently False, but it will be changed to True in Numba 0.59.0. See https://numba.readthedocs.io/en/stable/reference/deprecation.html#deprecation-of-object-mode-fall-back-behaviour-when-using-jit for details.
#   def memevidence(evidplay5, memplay5, evid5, evidarms5, memsuc5, memarms5, perms5, nag5, memshare5):
# /home/pallavi/python_pallavi_Dtop/confirm_bias_illusory_tuth_002/ill_confirm_bias_FNs_03_t0FAST_03cnt_vdisc_explore_prob.py:248: NumbaDeprecationWarning: The 'nopython' keyword argument was not supplied to the 'numba.jit' decorator. The implicit default value for this argument is currently False, but it will be changed to True in Numba 0.59.0. See https://numba.readthedocs.io/en/stable/reference/deprecation.html#deprecation-of-object-mode-fall-back-behaviour-when-using-jit for details.
#   def params_nsteps(explarray9, vdisc9, memplay9, idxf9, narms9, store9, perms9, memsuc9, memarms9, memshare9, memstore9, pulls9, nag9, con9, randunif90, pay9, params9, tol9, nsteps9):
# /home/pallavi/python_pallavi_Dtop/confirm_bias_illusory_tuth_002/ill_confirm_bias_FNs_03_t0FAST_03cnt_vdisc_explore_prob.py:261: NumbaDeprecationWarning: The 'nopython' keyword argument was not supplied to the 'numba.jit' decorator. The implicit default value for this argument is currently False, but it will be changed to True in Numba 0.59.0. See https://numba.readthedocs.io/en/stable/reference/deprecation.html#deprecation-of-object-mode-fall-back-behaviour-when-using-jit for details.
#   def persistence(idxf8, mem_depth8, mem_snap8, memplay8, mem_ds8, md_len8, ms_len8, nagf8, memf8):

# %%
# mp.set_start_method("fork")
start = time.perf_counter()

runs = 2000
numarms = 2
maxalphabeta = 4
# numagents = 50
# minagents = 4
# maxagents = 12
pulls = 1000
payprobs = np.asarray([.499, .5])
tollerance = 0
nsteps = 10
timesteps = 5*10**4

explprob = 0.00 #explore every expltstep many timesteps

mem_depth = [5, 10, 100, 1000]
mem_snap = [10, 100, 1000, 10000] #these values must be multiples of nsteps to get recorded


networktype = 'errandom'
erprobA = 0.5
erprobB = 2-2*(1-erprobA)**.5
print(f'erprobB = {erprobB}')

mem = 100 # must be greater than max numagents. if memshare = 0
memshare = 0 # setting this value and memstore to 0 gives the base model
memstore = 0 # setting this value and memshare to 0 gives the base model
variablediscount = 1

#number of threads
thrds = 25
# numba.set_num_threads(thrds)

for randomNG in ['PCG64DXSM']:
    bitNG = getattr(numpy.random, randomNG)
    for numagents in [4, 6, 9, 12, 15, 25]:
        sg = SeedSequence()
        rgs = [Generator(bitNG(s)) for s in sg.spawn(runs)]
        final_mp = np.zeros((runs, 2))
        depth_mp = np.zeros((runs, len(mem_snap)+1, len(mem_depth)))
        print('*********************************************')
        print('*********************************************')

        inputs = []

        with concurrent.futures.ProcessPoolExecutor(max_workers=thrds) as executor:
            future_to_confirm_bias_full = {executor.submit(confirm_bias_full, explprob, variablediscount, mem_snap, mem_depth, erprobB, mem, memshare, memstore, networktype, maxalphabeta, pulls, numagents, numarms, tollerance, payprobs, nsteps, timesteps, rgs, r): inputs for r in range(runs)}
            for future in concurrent.futures.as_completed(future_to_confirm_bias_full):
                inputs = future_to_confirm_bias_full[future]
                try:
                    data = future.result()
                except Exception as exc:
                    print(f'generated an exception: y? and {exc}')
                else:
                    final_mp[data[3]] = data[0:2]
                    depth_mp[data[3]] = data[2]


        final_mp = np.asarray(final_mp)
        suc_mp = np.asarray(final_mp[:,0])
        con_mp = np.asarray(final_mp[:,1])


        np.save(f'{pass_abc}expl{explprob}{randomNG}vdisc{variablediscount}t0fastNGconsensus_{networktype}_ifer{erprobA}_size{numagents}_t{tollerance}_mem_s_d_{mem}_{memshare}_{memstore}.npy', con_mp)
        np.save(f'{pass_abc}expl{explprob}{randomNG}vdisc{variablediscount}t0fastNGsuccess_{networktype}_ifer{erprobA}_size{numagents}_t{tollerance}_mem_s_d_{mem}_{memshare}_{memstore}.npy', suc_mp)
        np.save(f'{pass_abc}expl{explprob}{randomNG}vdisc{variablediscount}t0fastNGdepths_{networktype}_ifer{erprobA}_size{numagents}_t{tollerance}_mem_s_d_{mem}_{memshare}_{memstore}.npy', depth_mp)

        sucrate = np.sum(suc_mp)/runs
        conrate = np.sum(con_mp)/runs

        depth_mean = np.mean(depth_mp, axis=0)
        depth_std = np.std(depth_mp, axis=0)

        print('time:')
        print(datetime.datetime.now())

        print(f'M memory = {mem} S memshare = {memshare} D memstore = {memstore} discount factor = {variablediscount}')
        print(f'explore probability = {explprob}')
        print(f'for # agents = {numagents} success rate = {sucrate} consensus rate = {conrate}')
        print(f'using {randomNG} generator')
        print('network average memory depths:')
        print(depth_mean)
        print('depths standard deviation')
        print(depth_std)
        print(' ')
        print(' ')

finish = time.perf_counter()
print(f'Finished in {round(finish-start,0)/60} minutes')
# Out:
# erprobB = 0.5857864376269049
# *********************************************
# *********************************************
# time:
# 2024-04-13 09:06:34.421112
# M memory = 100 S memshare = 0 D memstore = 0 discount factor = 1
# explore probability = 0.0
# for # agents = 4 success rate = 0.6155 consensus rate = 1.0
# using PCG64DXSM generator
# network average memory depths:
# [[259.1010404 224.8001213  21.2028332   0.0000008]
#  [ 34.252       0.          0.          0.       ]
#  [238.083     203.7475      0.          0.       ]
#  [259.451     225.126      21.284       0.       ]
#  [259.295     224.9515     21.256       0.       ]]
# depths standard deviation
# [[14.49339529 16.74745811  8.10133135  0.00003577]
#  [ 4.18503238  0.          0.          0.        ]
#  [ 8.80937631 10.6676494   0.          0.        ]
#  [15.1362016  17.46078818  8.89125098  0.        ]
#  [15.11905999 17.63808798  9.08413254  0.        ]]
#
#
# *********************************************
# *********************************************
# time:
# 2024-04-13 09:08:33.298816
# M memory = 100 S memshare = 0 D memstore = 0 discount factor = 1
# explore probability = 0.0
# for # agents = 6 success rate = 0.7335 consensus rate = 1.0
# using PCG64DXSM generator
# network average memory depths:
# [[348.5940249 292.3797621  17.9668007   0.       ]
#  [ 56.352       0.          0.          0.       ]
#  [330.932     274.8065      0.          0.       ]
#  [349.1705    292.9825     17.956       0.       ]
#  [348.9775    292.668      18.03        0.       ]]
# depths standard deviation
# [[25.76871293 28.62707367  8.73680779  0.        ]
#  [ 5.56983806  0.          0.          0.        ]
#  [19.12752927 21.81254359  0.          0.        ]
#  [26.39258285 29.31530648  9.43578635  0.        ]
#  [26.4107174  29.27092031  9.56441844  0.        ]]
#
#
# *********************************************
# *********************************************
# time:
# 2024-04-13 09:10:50.854866
# M memory = 100 S memshare = 0 D memstore = 0 discount factor = 1
# explore probability = 0.0
# for # agents = 9 success rate = 0.8165 consensus rate = 1.0
# using PCG64DXSM generator
# network average memory depths:
# [[428.2816669 337.8108249  10.3523098   0.       ]
#  [ 90.333       0.          0.          0.       ]
#  [418.173     327.4595      0.          0.       ]
#  [428.491     338.208      10.3105      0.       ]
#  [428.6045    338.293      10.3415      0.       ]]
# depths standard deviation
# [[40.92454254 42.99065245  7.99313332  0.        ]
#  [ 7.16247939  0.          0.          0.        ]
#  [35.4124282  37.48749605  0.          0.        ]
#  [42.15230621 44.58974923  8.52496861  0.        ]
#  [41.90865161 43.91045606  8.5747815   0.        ]]
#
#
# *********************************************
# *********************************************
# time:
# 2024-04-13 09:13:29.645688
# M memory = 100 S memshare = 0 D memstore = 0 discount factor = 1
# explore probability = 0.0
# for # agents = 12 success rate = 0.852 consensus rate = 1.0
# using PCG64DXSM generator
# network average memory depths:
# [[458.0293823 337.6130626   4.4486908   0.       ]
#  [120.4385      0.          0.          0.       ]
#  [453.6475    333.394       0.          0.       ]
#  [458.268     337.8725      4.4205      0.       ]
#  [458.3515    338.0505      4.4595      0.       ]]
# depths standard deviation
# [[52.64802978 51.34248887  3.8841195   0.        ]
#  [ 8.50636337  0.          0.          0.        ]
#  [50.96811007 49.65065724  0.          0.        ]
#  [53.38183376 52.16074428  4.34634096  0.        ]
#  [53.55171284 52.4971423   4.30596792  0.        ]]
#
#
# *********************************************
# *********************************************
# time:
# 2024-04-13 09:16:30.492007
# M memory = 100 S memshare = 0 D memstore = 0 discount factor = 1
# explore probability = 0.0
# for # agents = 15 success rate = 0.8835 consensus rate = 1.0
# using PCG64DXSM generator
# network average memory depths:
# [[454.9764631 311.7488012   1.5852309   0.       ]
#  [143.063       0.          0.          0.       ]
#  [453.6525    310.1095      0.          0.       ]
#  [455.263     311.8795      1.6355      0.       ]
#  [454.9125    312.023       1.6075      0.       ]]
# depths standard deviation
# [[45.35524166 41.78696999  2.32508814  0.        ]
#  [10.1495828   0.          0.          0.        ]
#  [45.25983588 41.49817478  0.          0.        ]
#  [47.07417372 43.52254565  2.64643907  0.        ]
#  [46.586198   43.21534995  2.62839186  0.        ]]
#
#
# *********************************************
# *********************************************
# time:
# 2024-04-13 09:20:59.225223
# M memory = 100 S memshare = 0 D memstore = 0 discount factor = 1
# explore probability = 0.0
# for # agents = 25 success rate = 0.9335 consensus rate = 1.0
# using PCG64DXSM generator
# network average memory depths:
# [[333.5205118 176.8175165   0.0285331   0.       ]
#  [156.286       0.          0.          0.       ]
#  [333.685     176.709       0.          0.       ]
#  [333.1185    176.2165      0.024       0.       ]
#  [334.3965    177.506       0.0285      0.       ]]
# depths standard deviation
# [[36.70616327 26.3065551   0.05669637  0.        ]
#  [15.53493495  0.          0.          0.        ]
#  [39.14770459 28.62335269  0.          0.        ]
#  [38.71294948 28.08878117  0.16255461  0.        ]
#  [39.40969789 28.55970875  0.17230133  0.        ]]
#
#
# Finished in 16.2 minutes
